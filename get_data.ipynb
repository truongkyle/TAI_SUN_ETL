# %%
from utils.minio_client import MinIOConnector
import sys

# %%
try:
    minio = MinIOConnector()
except Exception as e:
    print(e)

# %%
bucket = "bronze"
file_key = "oracle_data/2504_TC_ABB_FILE/2025_12_01_1764579501178_0.parquet"

# %%
try:
    df = minio.read_parquet(bucket, file_key)
    print("\n --- Preview Data ---")
    print(df.head())
except Exception as e:
    print(e)
# Out:
# 2025-12-01 16:33:59,508 - INFO - 🔄 Đang bắt đầu đọc file: s3://bronze/oracle_data/2504_TC_ABB_FILE/2025_12_01_1764579501178_0.parquet
# 2025-12-01 16:33:59,859 - INFO - ✅ Đọc thành công! Kích thước: (54, 16)
#  --- Preview Data ---
#                         _airbyte_raw_id            _airbyte_extracted_at  \
# 0  019ad922-8947-735a-acbf-a8b258ccea38 2025-12-01 08:58:17.684000+00:00
# 1  019ad922-8955-775f-bfd1-c217b6430c3f 2025-12-01 08:58:17.684000+00:00
# 2  019ad922-8957-72c5-a05c-509042fc6645 2025-12-01 08:58:17.684000+00:00
# 3  019ad922-8957-7782-9aa9-4a3a49a4b775 2025-12-01 08:58:17.684000+00:00
# 4  019ad922-8957-7ea7-a9b2-db427fc26966 2025-12-01 08:58:17.684000+00:00
#
#                    _airbyte_meta  _airbyte_generation_id TC_ABB00  \
# 0  {'sync_id': 3, 'changes': []}                       1       00
# 1  {'sync_id': 3, 'changes': []}                       1       00
# 2  {'sync_id': 3, 'changes': []}                       1       00
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54 entries, 0 to 53
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   _airbyte_raw_id         54 non-null     object
#  1   _airbyte_extracted_at   54 non-null     datetime64[ms, UTC]
#  2   _airbyte_meta           54 non-null     object
#  3   _airbyte_generation_id  54 non-null     int64
#  4   TC_ABB00                54 non-null     object
#  5   TC_ABB01                54 non-null     object
#  6   TC_ABB02                54 non-null     float64
#  7   TC_ABB07                54 non-null     float64
#  8   TC_ABB08                0 non-null      object
#  9   TC_ABB24                0 non-null      object
#  10  TC_ABB25                0 non-null      float64
#  11  TC_ABB07F               54 non-null     float64
#  12  TC_ABB081               0 non-null      object
#  13  TC_ABB03_1              54 non-null     object
# ...

# %%
df = pd.read_parquet(path="./2025_12_01_1764579501178_0.parquet")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54 entries, 0 to 53
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   _airbyte_raw_id         54 non-null     object
#  1   _airbyte_extracted_at   54 non-null     datetime64[ms, UTC]
#  2   _airbyte_meta           54 non-null     object
#  3   _airbyte_generation_id  54 non-null     int64
#  4   TC_ABB00                54 non-null     object
#  5   TC_ABB01                54 non-null     object
#  6   TC_ABB02                54 non-null     float64
#  7   TC_ABB07                54 non-null     float64
#  8   TC_ABB08                0 non-null      object
#  9   TC_ABB24                0 non-null      object
#  10  TC_ABB25                0 non-null      float64
#  11  TC_ABB07F               54 non-null     float64
#  12  TC_ABB081               0 non-null      object
#  13  TC_ABB03_1              54 non-null     object
# ...

# %%
df.shape[0]
# Out:
# 54

# %%
df.shape[1]
# Out:
# 16

# %%
df.columns
# Out:
# Index(['_airbyte_raw_id', '_airbyte_extracted_at', '_airbyte_meta',
#        '_airbyte_generation_id', 'TC_ABB00', 'TC_ABB01', 'TC_ABB02',
#        'TC_ABB07', 'TC_ABB08', 'TC_ABB24', 'TC_ABB25', 'TC_ABB07F',
#        'TC_ABB081', 'TC_ABB03_1', 'TC_ABB03_2', 'TC_ABBACTI'],
#       dtype='object')
